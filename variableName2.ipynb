# %% [markdown]
# Pythonでは、全てのオブジェクトは名前空間である。
# os モジュールをimportするとosという名前が使用できるようになる

# %% [markdown]
# osはモジュールなので、モジュール内の関数を呼び出せる

# %% [markdown]
# osを文字列に紐づける

# %%
os = '適当な文字列'

# %% [markdown]
# 型を調べると変わっている
# 今度は関数呼び出しなどはできない

# %%
type(os)
# Out:
# str

# %%
del os

# %% [markdown]
# これでosという名前は無くなった
